# %%
import pickle
import numpy as np
import pandas as pd
import scipy.stats as stats

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Import custom project code
import sys
sys.path.append("/home/b1044271/Columbia/Aperiodic_sleep/helpers")

# %% [markdown]
# ## Load data

# %%
save_path = '/home/b1044271/Columbia/Results/2025/iEEG_results.pkl'

with open(save_path, 'rb') as f:
    loaded_data = pickle.load(f)
    PSDs_W = loaded_data['PSDs']['Wakefulness']
    PSDs_N2 = loaded_data['PSDs']['N2']
    PSDs_N3 = loaded_data['PSDs']['N3']
    PSDs_R = loaded_data['PSDs']['REM']

Freqs = np.load('/home/b1044271/Columbia/Results/2025/iEEG_Freqs.npy')

# %%
save_path = '/home/b1044271/Columbia/Results/2025/iEEG_results10.pkl'

with open(save_path, 'rb') as f:
    loaded_data = pickle.load(f)
    PSDs_W2 = loaded_data['PSDs']['Wakefulness']
    PSDs_N22 = loaded_data['PSDs']['N2']
    PSDs_N32 = loaded_data['PSDs']['N3']
    PSDs_R2 = loaded_data['PSDs']['REM']

Freqs10 = np.load('/home/b1044271/Columbia/Results/2025/iEEG_Freqs10.npy')

# %% [markdown]
# # REGIONS PSDS

# %%
array_list = [PSDs_W,PSDs_N2, PSDs_N3 ,PSDs_R, PSDs_W2,PSDs_N22, PSDs_N32 ,PSDs_R2]
titles =  ['Wake','N2','N3' ,'REM', 'Wake','N2','N3' ,'REM']

# Plotting
fig, ax = plt.subplots(2,4, sharex=True, sharey=True, figsize=(15,10.))

for i, V in enumerate(array_list):

    if i <=3:
        ax.flatten()[i].loglog(Freqs,np.transpose(V), linewidth=1.8)
    else:
        ax.flatten()[i].loglog(Freqs10,np.transpose(V), linewidth=1.8)
        
    ax.flatten()[i].set_title(titles[i], fontsize =22)
    ax.flatten()[i].set_ylim([10e-14 ,10e-9])       


fig.text(0.5, 0.04, 'log(frequency)', ha='center', fontsize = 20)
ax.flatten()[0].set_ylabel('log(power)', fontsize = 20)
ax.flatten()[4].set_ylabel('log(power)', fontsize = 20)

for axs in ax.flatten():
    axs.spines['top'].set_linewidth(1.5)
    axs.spines['right'].set_linewidth(1.5)
    axs.spines['bottom'].set_linewidth(1.5)
    axs.spines['left'].set_linewidth(1.5)   # Set the linewidth of the left axis line
    axs.tick_params(axis='both', which='both', direction='in', width=1.5, labelsize=16)  # Customize tick properties

plt.savefig("/home/b1044271/Columbia/Plots/Feb25/iEEG_PSDs_Regions.svg", dpi = 600)

# %% [markdown]
# # GROUP PSDs

# %%
# calculate descriptives
PSD_Wm = np.nanmean(PSDs_W,axis=0)
PSD_Ws = stats.sem(PSDs_W,0, nan_policy = 'omit')

PSD_Rs = stats.sem(PSDs_R,0, nan_policy = 'omit')
PSD_Rm = np.nanmean(PSDs_R,axis=0)

PSD_N2s = stats.sem(PSDs_N2,0, nan_policy = 'omit')
PSD_N2m = np.nanmean(PSDs_N2,axis=0)

PSD_N3s = stats.sem(PSDs_N3,0, nan_policy = 'omit')
PSD_N3m = np.nanmean(PSDs_N3,axis=0)

# plotting
plt.plot(Freqs,PSD_Wm, color = sns.color_palette("colorblind")[0], label='Wake', linewidth = 3)
plt.fill_between(Freqs,PSD_Wm-PSD_Ws, PSD_Wm+PSD_Ws,facecolor=sns.color_palette("colorblind")[0], alpha=0.25)

plt.plot(Freqs,PSD_N2m, color=sns.color_palette("colorblind")[7], label='N2', linewidth = 3)
plt.fill_between(Freqs,PSD_N2m-PSD_N2s, PSD_N2m+PSD_N2s,facecolor=sns.color_palette("colorblind")[7], alpha=0.25)

plt.plot(Freqs,PSD_N3m, color=sns.color_palette("colorblind")[2], label='N3', linewidth = 3)
plt.fill_between(Freqs,PSD_N3m-PSD_N3s, PSD_N3m+PSD_N3s,facecolor=sns.color_palette("colorblind")[2], alpha=0.25)

plt.plot(Freqs,PSD_Rm, color=sns.color_palette("colorblind")[3], label='R', linewidth = 3)
plt.fill_between(Freqs,PSD_Rm-PSD_Rs, PSD_Rm+PSD_Rs,facecolor=sns.color_palette("colorblind")[3], alpha=0.25)

# PLOT AVERAGE KNEE FREQUENCY Value
#sns.scatterplot(x=kf, y=kp, marker='o', color=['b','orange','green','r'], s=200, zorder=4, legend=False)

plt.ylabel('log(power)', fontsize=18)
plt.title('iEEG PSDs', fontsize = 24)
plt.xlabel('log(frequency)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(Freqs[0], Freqs[-1])
plt.legend(fontsize=20)
plt.yscale('log')
plt.xscale('log')
ax=plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='both', direction='in', width=1.5, labelsize=16)  # Customize tick properties
ax.spines['bottom'].set_linewidth(1.75)
ax.spines['left'].set_linewidth(1.75)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [48], line 3
#       1 # calculate descriptives
#       2 PSD_Wm = np.nanmean(PSDs_W,axis=0)
# ----> 3 PSD_Ws = stats.sem(PSDs_W,0, nan_policy = 'omit')
#       5 PSD_Rs = stats.sem(PSDs_R,0, nan_policy = 'omit')
#       6 PSD_Rm = np.nanmean(PSDs_R,axis=0)
#
# AttributeError: 'tuple' object has no attribute 'sem'

# %%
PSDs_W
# Out:
# array([[7.24912664e-11, 5.73174006e-11, 5.89333438e-11, ...,
#         3.62250614e-13, 3.75326925e-13, 4.51803388e-13],
#        [3.94163966e-10, 3.84042407e-10, 3.74489400e-10, ...,
#         8.74958411e-13, 7.35769592e-13, 7.62228460e-13],
#        [4.10315904e-11, 4.03376582e-11, 4.53521860e-11, ...,
#         1.62564065e-13, 1.46226431e-13, 1.25852148e-13],
#        ...,
#        [1.59791463e-10, 1.35789025e-10, 1.53293508e-10, ...,
#         3.90614125e-13, 3.34735624e-13, 3.82146559e-13],
#        [1.46830756e-10, 1.13467205e-10, 1.19902021e-10, ...,
#         7.45563462e-13, 7.85447671e-13, 1.05196268e-12],
#        [1.08862425e-10, 1.20311503e-10, 1.03864044e-10, ...,
#         7.21561400e-13, 6.54020358e-13, 6.48654543e-13]])
